# %%
print('приветики')
# Out:
# приветики

# %%
number = 254
print(number)
print(float(number))
# Out:
# 254
# 254.0

# %%
year = 365
week = 7
a = year // week
print(c)
b = year % week
print(d)
# Out:
# 52
# 1

# %%
months_in_year = 12
c = round(year / months, 2)
print(c)
# Out:
# 30.42

# %%
hours_in_year = year * 24
print(hours_in_year)
minutes_in_year = hours_in_year * 60
print(minutes_in_year)
seconds_in_year = minutes_in_year * 60
print(seconds_in_year)
# Out:
# 8760
# 525600
# 31536000

# %%
g = (pow(katet1, 2) + pow(katet2, 2)) ** 0.5
print(g)
# Out:
# 8.06225774829855

# %%
katet1 = 4
katet2 = 7
summa = g + katet1 + katet2
print(summa)
maximal = max(g, katet1, katet2)
print(maximal)
minimal = min(g, katet1, katet2)
print(minimal)
# Out:
# 19.06225774829855
# 8.06225774829855
# 4

# %%
name = 'Ярослав'
surname = 'Мартыненко'
print('"""Меня зовут ' + name, surname + ' и я учу Python!!!"""')
# Out:
# """Меня зовут Ярослав Мартыненко и я учу Python!!!"""

# %%
aa = 'Карл у Клары украл кораллы, а Клара у Карла украла кларнет. Если бы Карл у Клары не украл кораллы, то Клара у Карла не \
украла б кларнет'
print(aa.count('а'))
# Out:
# 23

# %%
print(aa.lower())
print(aa.upper())
# Out:
# карл у клары украл кораллы, а клара у карла украла кларнет. если бы карл у клары не украл кораллы, то клара у карла не украла б кларнет
# КАРЛ У КЛАРЫ УКРАЛ КОРАЛЛЫ, А КЛАРА У КАРЛА УКРАЛА КЛАРНЕТ. ЕСЛИ БЫ КАРЛ У КЛАРЫ НЕ УКРАЛ КОРАЛЛЫ, ТО КЛАРА У КАРЛА НЕ УКРАЛА Б КЛАРНЕТ

# %%
print(aa.capitalize())
# Out:
# Карл у клары украл кораллы, а клара у карла украла кларнет. если бы карл у клары не украл кораллы, то клара у карла не украла б кларнет

# %%
print('Кларнет' in aa)
print('кларнет' in aa)
print('КЛАРНЕТ' in aa)
# Out:
# False
# True
# False
